# %%
import pandas as pd
import sklearn as sk
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('boston_house_prices.csv')
data
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  \
# 0    0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296
# 1    0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242
# 2    0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242
# 3    0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222
# 4    0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 501  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273
# 502  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273
# 503  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273
# 504  0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889    1  273
# 505  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273
#
#      PTRATIO       B  LSTAT  MEDV
# 0       15.3  396.90   4.98  24.0
# 1       17.8  396.90   9.14  21.6
# 2       17.8  392.83   4.03  34.7
# 3       18.7  394.63   2.94  33.4
# 4       18.7  396.90   5.33  36.2
# ..       ...     ...    ...   ...
# 501     21.0  391.99   9.67  22.4
# 502     21.0  396.90   9.08  20.6
# 503     21.0  396.90   5.64  23.9
# 504     21.0  393.45   6.48  22.0
# 505     21.0  396.90   7.88  11.9
#
# [506 rows x 14 columns]

# %%
dataset = pd.DataFrame(data)

# %%
dataset
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  \
# 0    0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296
# 1    0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242
# 2    0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242
# 3    0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222
# 4    0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 501  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273
# 502  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273
# 503  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273
# 504  0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889    1  273
# 505  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273
#
#      PTRATIO       B  LSTAT  MEDV
# 0       15.3  396.90   4.98  24.0
# 1       17.8  396.90   9.14  21.6
# 2       17.8  392.83   4.03  34.7
# 3       18.7  394.63   2.94  33.4
# 4       18.7  396.90   5.33  36.2
# ..       ...     ...    ...   ...
# 501     21.0  391.99   9.67  22.4
# 502     21.0  396.90   9.08  20.6
# 503     21.0  396.90   5.64  23.9
# 504     21.0  393.45   6.48  22.0
# 505     21.0  396.90   7.88  11.9
#
# [506 rows x 14 columns]

# %%
X = dataset
y = data["MEDV"]

# %%
y
# Out:
# 0      24.0
# 1      21.6
# 2      34.7
# 3      33.4
# 4      36.2
#        ...
# 501    22.4
# 502    20.6
# 503    23.9
# 504    22.0
# 505    11.9
# Name: MEDV, Length: 506, dtype: float64

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, Y_train, Y_test = train_test_split( X , y , test_size = 0.30 , random_state = 42 )

# %%
X_train
# Out:
#          CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  \
# 5     0.02985   0.0   2.18     0  0.458  6.430  58.7  6.0622    3  222
# 116   0.13158   0.0  10.01     0  0.547  6.176  72.5  2.7301    6  432
# 45    0.17142   0.0   6.91     0  0.448  5.682  33.8  5.1004    3  233
# 16    1.05393   0.0   8.14     0  0.538  5.935  29.3  4.4986    4  307
# 468  15.57570   0.0  18.10     0  0.580  5.926  71.0  2.9084   24  666
# ..        ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 106   0.17120   0.0   8.56     0  0.520  5.836  91.9  2.2110    5  384
# 270   0.29916  20.0   6.96     0  0.464  5.856  42.1  4.4290    3  223
# 348   0.01501  80.0   2.01     0  0.435  6.635  29.7  8.3440    4  280
# 435  11.16040   0.0  18.10     0  0.740  6.629  94.6  2.1247   24  666
# 102   0.22876   0.0   8.56     0  0.520  6.405  85.4  2.7147    5  384
#
#      PTRATIO       B  LSTAT  MEDV
# 5       18.7  394.12   5.21  28.7
# 116     17.8  393.30  12.04  21.2
# 45      17.9  396.90  10.21  19.3
# 16      21.0  386.85   6.58  23.1
# 468     20.2  368.74  18.13  19.1
# ..       ...     ...    ...   ...
# 106     20.9  395.67  18.66  19.5
# 270     18.6  388.65  13.00  21.1
# 348     17.0  390.94   5.99  24.5
# 435     20.2  109.85  23.27  13.4
# 102     20.9   70.80  10.63  18.6
#
# [354 rows x 14 columns]

# %%
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
model = LinearRegression()
model.fit(X_train,Y_train)
# Out:
# LinearRegression()

# %%
X_train = scaler.fit_transform(X_train)

# %%
X_test = scaler.transform(X_test)

# %%
from sklearn.model_selection import cross_val_score

# %%
mse = cross_val_score(model, X_train, Y_train, scoring = 'neg_mean_squared_error',cv = 9)

# %%
np.mean(mse)
# Out:
# -3.275912794712645e-27

# %%
reg = model.predict(X_test)

# %%
reg
# Out:
# array([ 0.04053124,  1.14775636, -1.21767912, -0.06012559, -0.90312653,
#        -0.41242449, -0.68923077, -1.16735071, -0.46275291, -0.81505181,
#        -0.22369294, -0.55082763, -2.04809796, -0.26143925, -0.60115605,
#         0.82062166, -0.56340973, -1.64547065,  3.3622066 , -1.1547686 ,
#         0.2418449 ,  0.73254694, -1.33091806, -0.110454  , -1.1421865 ,
#        -1.19251492, -0.37467818, -1.05411178, -0.19852873, -0.62632025,
#        -0.02237928,  0.06569545, -1.04152967, -0.31176766, -0.52566342,
#        -0.48791711,  1.43714474, -0.47533501,  0.14118807,  0.01536703,
#        -0.4501708 ,  0.61930801,  3.3622066 , -0.73955918, -0.0852898 ,
#        -1.02894757, -1.28058964,  0.11602386, -0.42500659,  0.09085965,
#        -0.55082763,  1.52521947, -1.01636546,  0.40541224,  2.54436986,
#        -0.26143925, -0.61373815,  0.65705432,  0.07827755, -0.60115605,
#         0.21668069,  1.52521947,  1.03451743, -0.38726028,  0.10344176,
#        -0.41242449, -1.28058964,  0.19151648,  0.9464427 , -1.33091806,
#        -0.41242449,  0.05311334, -1.56997802, -0.33693187, -0.31176766,
#        -2.29974003, -0.39984239,  3.17347504, -1.55739592, -2.04809796,
#        -0.29918556, -0.76472339, -0.29918556, -1.70838116, -0.48791711,
#         0.71996484, -0.86538022,  0.21668069,  0.21668069, -0.7773055 ,
#        -0.00979717, -1.62030644, -0.46275291, -0.76472339,  0.53123328,
#        -0.03496138,  3.3622066 , -0.67664867, -1.72096327, -0.76472339,
#        -0.0978719 , -0.23627504, -1.41899278, -0.42500659, -0.48791711,
#        -1.24284333, -0.63890236,  0.16635228, -0.27402135,  0.17893438,
#        -1.8342022 ,  0.53123328, -0.32434977,  1.6258763 ,  1.04709953,
#        -1.45673909,  2.07883203, -1.17993281, -0.18594663,  0.05311334,
#        -0.71439498,  0.14118807, -1.8216201 , -0.51308132,  0.254427  ,
#        -0.36209608, -0.02237928,  1.83977206, -0.96603705,  2.78342983,
#        -0.95345495, -0.0852898 , -1.10444019, -0.57599184, -0.68923077,
#        -0.90312653, -0.33693187,  1.04709953,  0.73254694, -0.96603705,
#        -0.72697708, -0.0978719 , -0.48791711, -0.50049922, -1.85936641,
#        -0.33693187, -0.7898876 , -0.7773055 , -1.10444019,  3.3622066 ,
#        -1.1296044 , -1.34350016])

# %%
import seaborn as sns
sns.displot(reg-Y_test,kind='kde')

# %%
from sklearn.metrics import r2_score
score = r2_score(reg,Y_test)
score
# Out:
# -444.37461296674525
